# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Ahmed Rehman\Downloads\Sleep_health_and_lifestyle_dataset.csv')
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.shape[1] #number of columns
# Out:
# 13

# %%
df.shape[0] #number of rows
# Out:
# 374

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
round(df['Age'].mean(), 1)
# Out:
# 42.2

# %%
df['Heart Rate'].min()
# Out:
# 65

# %%
df['Occupation'].nunique()
# Out:
# 11

# %%
df['Occupation'].unique()
# Out:
# array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#        'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#        'Salesperson', 'Manager'], dtype=object)

# %%
df.duplicated.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.duplicated.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
#There is no duplicated data but want to show how to remove it
df.drop_duplicates(inplace=True)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#Finding any Null Data Rows
df.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 2
#       1 #Removing any Null Data Rows
# ----> 2 df.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %scipy
from scipy.stats import norm
# %matplotlib inline
# Out:
# UsageError: Line magic function `%scipy` not found.

# %%
plt.figure(figsize=(10,5))
sns.distplot(a=df["Age"],bins=20, kde=True, color='#ef8a47')
plt.show()
# Out:
# C:\Users\Ahmed Rehman\AppData\Local\Temp\ipykernel_13316\3399248039.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df["Age"],bins=20, kde=True, color='#ef8a47')

# %%
df['BMI Category'].value_counts()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %%
women = df[df['Gender'] == 'Women']
women['BMI Category'].median()
# Out:
# nan

# %%
df['Physical Activity Level'].describe()
# Out:
# count    374.000000
# mean      59.171123
# std       20.830804
# min       30.000000
# 25%       45.000000
# 50%       60.000000
# 75%       75.000000
# max       90.000000
# Name: Physical Activity Level, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=df['Physical Activity Level'], y=df['Heart Rate'], ci=None)
plt.show()
# Out:
# C:\Users\Ahmed Rehman\AppData\Local\Temp\ipykernel_13316\2800843835.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df['Physical Activity Level'], y=df['Heart Rate'], ci=None)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x=df['Daily Steps'], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(data=df, x=df['Heart Rate'])
plt.show()

# %%
Q1 = df['Heart Rate'].quantile(.25)
Q3 = df['Heart Rate'].quantile(.75)
IQR = Q3 - Q1 
IQR
# Out:
# 4.0

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df.corr()
#
# File c:\Users\Ahmed Rehman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Ahmed Rehman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
sns.pairplot(df)

# %%
sns.set(style='whitegrid')
f=plt.figure(figsize=(10,5))
sns.regplot(x=df['Heart Rate'], y=df['Daily Steps'], scatter_kws={'alpha':0.5, 's':5}, line_kws={'color':'red'})
plt.title('Heart Rate vs Daily Steps')
plt.show()

# %%
plt.subplot()
sns.set(style='whitegrid')
sns.scatterplot(x=df['Sleep Duration'], y=df['Physical Activity Level'], s=20,alpha=.5)
plt.plot(c='red', linewidth=2)
plt.title('Sleep Duration vs Phyiscal Activity')
plt.show()

# %%
sns.histplot(df['Daily Steps'], bins=10, color='green')
# Out:
# <AxesSubplot: xlabel='Daily Steps', ylabel='Count'>

# %%
df['Age'].mean()
# Out:
# 42.18449197860963

# %%
sns.histplot(data=df, stat='count', multiple='stack', x=df['Stress Level'], kde=True, palette='pastel', hue=df['Gender'], element='bars', legend=True)
# Out:
# <AxesSubplot: xlabel='Stress Level', ylabel='Count'>
